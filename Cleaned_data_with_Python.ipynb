# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [raw]
# Using the Corona Virus Data Sets given , Create an Interactive Dashboard along with the
# answers to the below given problem statements.
#
# 1. What is the proportionality of genders in regard to no of affected people & dead people.
# 2. Highlight the time duration takes from the day admitted to the death.
# 3. Excluding Wuhan, report the disease transmission in other provinces.
# 4. Which symptom becomes the most common of the dead people?
# 5. Which age people are most likely to get caught Covid-19?

# %% [markdown]
# ## Dealing with Null values of Relevant columns based on problem statements

# %%
df=pd.read_csv("COVID19_open_line_list_cleaned_1.csv")

# %%
df.head()
# Out:
#     ID   age     sex                        city province country  \
# 0  1.0  30.0    male     Chaohu City, Hefei City    Anhui   China
# 1  2.0  47.0    male  Baohe District, Hefei City    Anhui   China
# 2  3.0  49.0    male  High-Tech Zone, Hefei City    Anhui   China
# 3  4.0  47.0  female  High-Tech Zone, Hefei City    Anhui   China
# 4  5.0  50.0  female  Feidong County, Hefei City    Anhui   China
#
#    wuhan(0)_not_wuhan(1)   latitude   longitude geo_resolution  ... outcome  \
# 0                    1.0  31.646960  117.716600         admin3  ...     NaN
# 1                    1.0  31.778630  117.331900         admin3  ...     NaN
# 2                    1.0  31.828313  117.224844          point  ...     NaN
# 3                    1.0  31.828313  117.224844          point  ...     NaN
# 4                    1.0  32.001230  117.568100         admin3  ...     NaN
#
#   date_death_or_discharge notes_for_discussion        location  \
# ...

# %%
df.columns
# Out:
# Index(['ID', 'age', 'sex', 'city', 'province', 'country',
#        'wuhan(0)_not_wuhan(1)', 'latitude', 'longitude', 'geo_resolution',
#        'date_onset_symptoms', 'date_admission_hospital', 'date_confirmation',
#        'symptoms', 'lives_in_Wuhan', 'travel_history_dates',
#        'travel_history_location', 'reported_market_exposure',
#        'additional_information', 'chronic_disease_binary', 'chronic_disease',
#        'source', 'sequence_available', 'outcome', 'date_death_or_discharge',
#        'notes_for_discussion', 'location', 'admin3', 'admin2', 'admin1',
#        'country_new', 'admin_id', 'data_moderator_initials'],
#       dtype='object')

# %%
df
# Out:
#             ID    age     sex                                       city  \
# 0          1.0     30    male                    Chaohu City, Hefei City
# 1          2.0     47    male                 Baohe District, Hefei City
# 2          3.0     49    male                 High-Tech Zone, Hefei City
# 3          4.0     47  female                 High-Tech Zone, Hefei City
# 4          5.0     50  female                 Feidong County, Hefei City
# 5          6.0    NaN     NaN                                 Lu'an City
# 6          7.0     42  female                                Fuyang City
# 7          8.0    NaN  female                               Huaibei City
# 8          9.0     59  female                               Huainan City
# 9         10.0     30    male                                 Hefei City
# 10        11.0    NaN     NaN                                 Lu'an City
# 11        12.0     39    male                                Fuyang City
# ...

# %%
df.drop(axis=1,columns=[ 'Unnamed: 33','Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36'],inplace=True)

# %%
df.head()
# Out:
#     ID age     sex                        city province country  \
# 0  1.0  30    male     Chaohu City, Hefei City    Anhui   China
# 1  2.0  47    male  Baohe District, Hefei City    Anhui   China
# 2  3.0  49    male  High-Tech Zone, Hefei City    Anhui   China
# 3  4.0  47  female  High-Tech Zone, Hefei City    Anhui   China
# 4  5.0  50  female  Feidong County, Hefei City    Anhui   China
#
#    wuhan(0)_not_wuhan(1)   latitude   longitude geo_resolution  ... outcome  \
# 0                    1.0  31.646960  117.716600         admin3  ...     NaN
# 1                    1.0  31.778630  117.331900         admin3  ...     NaN
# 2                    1.0  31.828313  117.224844          point  ...     NaN
# 3                    1.0  31.828313  117.224844          point  ...     NaN
# 4                    1.0  32.001230  117.568100         admin3  ...     NaN
#
#   date_death_or_discharge notes_for_discussion        location  \
# ...

# %%
df['age'].value_counts()
# Out:
# 33.0    29
# 50.0    29
# 49.0    27
# 30.0    26
# 35.0    26
# 42.0    24
# 43.0    24
# 47.0    24
# 56.0    23
# 41.0    23
# 39.0    23
# 38.0    23
# 45.0    23
# 37.0    23
# 55.0    22
# 28.0    20
# 51.0    20
# 52.0    19
# 25.0    19
# 40.0    19
# 36.0    19
# 32.0    19
# 24.0    19
# 29.0    19
# 60.0    19
# 27.0    18
# 44.0    17
# 34.0    17
# 64.0    17
# 54.0    16
#         ..
# 16.0     5
# 75.0     5
# 80.0     5
# 78.0     5
# 17.0     5
# 2.0      4
# 15.0     4
# 8.0      4
# 71.0     4
# 4.0      3
# 7.0      3
# 9.0      3
# 88.0     3
# 82.0     3
# 1.0      2
# 12.0     2
# 19.0     2
# 79.0     2
# 18.0     2
# 11.0     2
# 5.0      2
# 74.0     2
# 76.0     2
# 84.0     2
# 96.0     1
# 94.0     1
# 3.0      1
# 81.0     1
# 83.0     1
# 87.0     1
# Name: age, Length: 85, dtype: int64

# %%
df['age'].mean()
# Out:
# 44.05711422845691

# %%
df.dropna(how='all',inplace=True)

# %%
df.to_csv('COVID19_open_line_list_cleaned_4.csv',index=False)

# %%
df.dropna(how='any',subset=['age','sex','province'],inplace=True)

# %%
df
# Out:
#             ID   age     sex                            city  \
# 0          1.0  30.0    male         Chaohu City, Hefei City
# 1          2.0  47.0    male      Baohe District, Hefei City
# 2          3.0  49.0    male      High-Tech Zone, Hefei City
# 3          4.0  47.0  female      High-Tech Zone, Hefei City
# 4          5.0  50.0  female      Feidong County, Hefei City
# 6          7.0  42.0  female                     Fuyang City
# 8          9.0  59.0  female                    Huainan City
# 9         10.0  30.0    male                      Hefei City
# 11        12.0  39.0    male                     Fuyang City
# 13        14.0  38.0  female                    Chizhou City
# 14        15.0  45.0    male                     Bengbu City
# 17        18.0  33.0  female              Changping District
# 20        21.0  37.0    male                Fengtai District
# 21        22.0  39.0    male                Haidian District
# ...

# %%
df.columns
# Out:
# Index(['ID', 'age', 'sex', 'city', 'province', 'country',
#        'wuhan(0)_not_wuhan(1)', 'latitude', 'longitude', 'geo_resolution',
#        'date_onset_symptoms', 'date_admission_hospital', 'date_confirmation',
#        'symptoms', 'lives_in_Wuhan', 'travel_history_dates',
#        'travel_history_location', 'reported_market_exposure',
#        'additional_information', 'chronic_disease_binary', 'chronic_disease',
#        'source', 'sequence_available', 'outcome', 'date_death_or_discharge',
#        'notes_for_discussion', 'location', 'admin3', 'admin2', 'admin1',
#        'country_new', 'admin_id', 'data_moderator_initials'],
#       dtype='object')

# %%
df['city'].fillna('None',inplace=True)

# %%
df['country'].fillna('None',inplace=True)

# %%
df['latitude'].fillna(0,inplace=True)

# %%
df['longitude'].fillna(0,inplace=True)

# %%
df['geo_resolution'].fillna('None',inplace=True)

# %%
df['date_onset_symptoms']=df['date_onset_symptoms'].replace('end of December 2019',np.nan)

# %%
df1=df[['ID', 'age', 'sex', 'city', 'province', 'country','wuhan(0)_not_wuhan(1)', 'latitude', 'longitude', 'geo_resolution']]

# %% [markdown]
# ## Extraction and more Cleaning of relevant columns for a given problem statements

# %%
df1.head()
# Out:
#     ID   age     sex                        city province country  \
# 0  1.0  30.0    male     Chaohu City, Hefei City    Anhui   China
# 1  2.0  47.0    male  Baohe District, Hefei City    Anhui   China
# 2  3.0  49.0    male  High-Tech Zone, Hefei City    Anhui   China
# 3  4.0  47.0  female  High-Tech Zone, Hefei City    Anhui   China
# 4  5.0  50.0  female  Feidong County, Hefei City    Anhui   China
#
#    wuhan(0)_not_wuhan(1)   latitude   longitude geo_resolution
# 0                    1.0  31.646960  117.716600         admin3
# 1                    1.0  31.778630  117.331900         admin3
# 2                    1.0  31.828313  117.224844          point
# 3                    1.0  31.828313  117.224844          point
# 4                    1.0  32.001230  117.568100         admin3

# %%
df1.dtypes
# Out:
# ID                       float64
# age                      float64
# sex                       object
# city                      object
# province                  object
# country                   object
# wuhan(0)_not_wuhan(1)    float64
# latitude                 float64
# longitude                float64
# geo_resolution            object
# dtype: object

# %%
df.columns
# Out:
# Index(['ID', 'age', 'sex', 'city', 'province', 'country',
#        'wuhan(0)_not_wuhan(1)', 'latitude', 'longitude', 'geo_resolution',
#        'date_onset_symptoms', 'date_admission_hospital', 'date_confirmation',
#        'symptoms', 'lives_in_Wuhan', 'travel_history_dates',
#        'travel_history_location', 'reported_market_exposure',
#        'additional_information', 'chronic_disease_binary', 'chronic_disease',
#        'source', 'sequence_available', 'outcome', 'date_death_or_discharge',
#        'notes_for_discussion', 'location', 'admin3', 'admin2', 'admin1',
#        'country_new', 'admin_id', 'data_moderator_initials'],
#       dtype='object')

# %%
df2=df[['city', 'province', 'country','wuhan(0)_not_wuhan(1)','symptoms','lives_in_Wuhan','date_admission_hospital', 'outcome', 'date_death_or_discharge']]

# %%
df2.head()
# Out:
#                          city province country  wuhan(0)_not_wuhan(1)  \
# 0     Chaohu City, Hefei City    Anhui   China                    1.0
# 1  Baohe District, Hefei City    Anhui   China                    1.0
# 2  High-Tech Zone, Hefei City    Anhui   China                    1.0
# 3  High-Tech Zone, Hefei City    Anhui   China                    1.0
# 4  Feidong County, Hefei City    Anhui   China                    1.0
#
#   symptoms lives_in_Wuhan date_admission_hospital outcome  \
# 0      NaN            yes              20.01.2020     NaN
# 1      NaN             no              21.01.2020     NaN
# 2      NaN             no              20.01.2020     NaN
# 3      NaN             no              20.01.2020     NaN
# 4      NaN             no              21.01.2020     NaN
#
#   date_death_or_discharge
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN

# %%
df2['symptoms'].fillna('None',inplace=True)
# Out:
# C:\Users\Lenovo\Anaconda3\lib\site-packages\pandas\core\generic.py:6130: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
df2.head()
# Out:
#                          city province country  wuhan(0)_not_wuhan(1)  \
# 0     Chaohu City, Hefei City    Anhui   China                    1.0
# 1  Baohe District, Hefei City    Anhui   China                    1.0
# 2  High-Tech Zone, Hefei City    Anhui   China                    1.0
# 3  High-Tech Zone, Hefei City    Anhui   China                    1.0
# 4  Feidong County, Hefei City    Anhui   China                    1.0
#
#   symptoms lives_in_Wuhan date_admission_hospital outcome  \
# 0     None            yes              20.01.2020     NaN
# 1     None             no              21.01.2020     NaN
# 2     None             no              20.01.2020     NaN
# 3     None             no              20.01.2020     NaN
# 4     None             no              21.01.2020     NaN
#
#   date_death_or_discharge
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN

# %%
df2.dropna(subset=['outcome'],inplace=True)
# Out:
# C:\Users\Lenovo\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df2['outcome'].value_counts()
# Out:
# discharge                                         81
# stable                                            34
# death                                             12
# recovered                                          1
# critical condition, intubated as of 14.02.2020     1
# 05.02.2020                                         1
# Name: outcome, dtype: int64

# %%
df2['outcome'].replace("died",'death',inplace=True)
# Out:
# C:\Users\Lenovo\Anaconda3\lib\site-packages\pandas\core\generic.py:6586: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
df2['outcome'].replace("Discharged",'discharge',inplace=True)

# %%
df2.drop(index=df[df['outcome']=='05.02.2020 '].index,inplace=True)

# %%
df2.head()
# Out:
#                    city      province country  wuhan(0)_not_wuhan(1)  \
# 18      Daxing District       Beijing   China                    1.0
# 55        Wushan County     Chongqing   China                    1.0
# 161  Fangchenggang City       Guangxi   China                    1.0
# 175         Suihua City  Heilongjiang   China                    1.0
# 185           Hong Kong     Hong Kong   China                    1.0
#
#                      symptoms lives_in_Wuhan date_admission_hospital  \
# 18   fatigue, fever, headache             no              08.01.2020
# 55             fatigue, fever            NaN              15.01.2020
# 161                discomfort             no              23.01.2020
# 175                      None            NaN                     NaN
# 185              cough, fever            yes              21.01.2020
#
#        outcome date_death_or_discharge
# 18   discharge              24.01.2020
# 55   discharge              29.01.2020
# ...

# %%
df2.columns
# Out:
# Index(['city', 'province', 'country', 'wuhan(0)_not_wuhan(1)', 'symptoms',
#        'lives_in_Wuhan', 'date_admission_hospital', 'outcome',
#        'date_death_or_discharge'],
#       dtype='object')

# %%
df2.dtypes
# Out:
# city                        object
# province                    object
# country                     object
# wuhan(0)_not_wuhan(1)      float64
# symptoms                    object
# lives_in_Wuhan              object
# date_admission_hospital     object
# outcome                     object
# date_death_or_discharge     object
# dtype: object

# %%
df2['date_admission_hospital']=pd.to_datetime(df2['date_admission_hospital'],format='%d.%m.%Y')
# Out:
# C:\Users\Lenovo\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df2['date_death_or_discharge'].value_counts()
# Out:
# 26.02.2020    8
# 17.02.2020    6
# 18.02.2020    5
# 22.02.2020    5
# 10.02.2020    4
# 12.02.2020    4
# 25.02.2020    4
# 05.02.2020    4
# 27.02.2020    3
# 14.02.2020    3
# 09.02.2020    3
# 02.02.2020    3
# 23.02.2020    2
# 24.02.2020    2
# 20.02.2020    2
# 13.02.2020    2
# 16.02.2020    2
# 08.02.2020    2
# 19.02.2020    2
# 28.01.2020    2
# 30.01.2020    1
# 29.01.2020    1
# 17.01.2020    1
# discharge     1
# 21.02.2020    1
# 03.02.2020    1
# 07.02.2020    1
# 31.01.2020    1
# 01.02.2020    1
# 06.02.2020    1
# 02.02.2021    1
# 23.01.2020    1
# 28.02.2020    1
# 15.02.2020    1
# 27.01.2020    1
# 15.01.2020    1
# 24.01.2020    1
# Name: date_death_or_discharge, dtype: int64

# %%
df2.drop(index=df2[df2['date_death_or_discharge']=='discharge'].index,inplace=True)

# %%
df2['date_death_or_discharge'].value_counts()
# Out:
# 26.02.2020    8
# 17.02.2020    6
# 18.02.2020    5
# 22.02.2020    5
# 10.02.2020    4
# 12.02.2020    4
# 25.02.2020    4
# 05.02.2020    4
# 02.02.2020    3
# 14.02.2020    3
# 09.02.2020    3
# 27.02.2020    3
# 13.02.2020    2
# 24.02.2020    2
# 16.02.2020    2
# 08.02.2020    2
# 23.02.2020    2
# 19.02.2020    2
# 28.01.2020    2
# 20.02.2020    2
# 29.01.2020    1
# 17.01.2020    1
# 30.01.2020    1
# 23.01.2020    1
# 21.02.2020    1
# 07.02.2020    1
# 31.01.2020    1
# 01.02.2020    1
# 06.02.2020    1
# 03.02.2020    1
# 02.02.2021    1
# 28.02.2020    1
# 15.02.2020    1
# 27.01.2020    1
# 15.01.2020    1
# 24.01.2020    1
# Name: date_death_or_discharge, dtype: int64

# %%
df2['date_death_or_discharge']=pd.to_datetime(df2['date_death_or_discharge'],format='%d.%m.%Y')
# Out:
# C:\Users\Lenovo\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df2.dtypes
# Out:
# city                               object
# province                           object
# country                            object
# wuhan(0)_not_wuhan(1)             float64
# symptoms                           object
# lives_in_Wuhan                     object
# date_admission_hospital    datetime64[ns]
# outcome                            object
# date_death_or_discharge    datetime64[ns]
# dtype: object

# %%
df1.dtypes
# Out:
# ID                       float64
# age                      float64
# sex                       object
# city                      object
# province                  object
# country                   object
# wuhan(0)_not_wuhan(1)    float64
# latitude                 float64
# longitude                float64
# geo_resolution            object
# dtype: object

# %%
df1.to_csv('COVID19_open_line_list_cleaned_final_part_1.csv',index=False)

# %%
df2.to_csv('COVID19_open_line_list_cleaned_final_part_2.csv',index=False)

# %%
df1.head()
# Out:
#     ID   age     sex                        city province country  \
# 0  1.0  30.0    male     Chaohu City, Hefei City    Anhui   China
# 1  2.0  47.0    male  Baohe District, Hefei City    Anhui   China
# 2  3.0  49.0    male  High-Tech Zone, Hefei City    Anhui   China
# 3  4.0  47.0  female  High-Tech Zone, Hefei City    Anhui   China
# 4  5.0  50.0  female  Feidong County, Hefei City    Anhui   China
#
#    wuhan(0)_not_wuhan(1)   latitude   longitude geo_resolution
# 0                    1.0  31.646960  117.716600         admin3
# 1                    1.0  31.778630  117.331900         admin3
# 2                    1.0  31.828313  117.224844          point
# 3                    1.0  31.828313  117.224844          point
# 4                    1.0  32.001230  117.568100         admin3

# %%
df1[df1['country'].isnull()]
# Out:
# Empty DataFrame
# Columns: [ID, age, sex, city, province, country, wuhan(0)_not_wuhan(1), latitude, longitude, geo_resolution]
# Index: []
